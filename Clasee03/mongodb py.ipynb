# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://sharonarandiav:ejemplocontrasenia@clusterclasebigdata.s8yqtcq.mongodb.net/?retryWrites=true&w=majority&appName=ClusterClaseBigData"

# %%
import pymongo

# %%
client = pymongo.MongoClient(uri)
db = client['sample_airbnb']
collections = db['listingsAndReviews']

# %%
collections
# Out:
# Collection(Database(MongoClient(host=['ac-epwqvbp-shard-00-00.s8yqtcq.mongodb.net:27017', 'ac-epwqvbp-shard-00-02.s8yqtcq.mongodb.net:27017', 'ac-epwqvbp-shard-00-01.s8yqtcq.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='ClusterClaseBigData', authsource='admin', replicaset='atlas-fwbhv0-shard-0', tls=True), 'sample_airbnb'), 'listingsAndReviews')

# %%
data = list(collections.find().limit(50))

# %%
data
# Out:
# [{'_id': '10117617',
#   'listing_url': 'https://www.airbnb.com/rooms/10117617',
#   'name': 'A Casa Alegre é um apartamento T1.',
#   'summary': 'Para 2 pessoas. Vista de mar a 150 mts. Prédio com 2 elevadores. Tem: - quarto com roupeiro e cama de casal (colchão magnetizado); - cozinha: placa de discos, exaustor, frigorifico, micro-ondas e torradeira; casa de banho completa; - sala e varanda.',
# ...

# %%
features = ['accommodates','bedrooms',
  'beds',
  'number_of_reviews']

# %%
features
# Out:
# ['accommodates', 'bedrooms', 'beds', 'number_of_reviews']

# %%
target='price'

# %%
import pandas as pd

# %%
data = pd.DataFrame(data)
data
# Out:
#          _id                            listing_url  \
# 0   10117617  https://www.airbnb.com/rooms/10117617
# 1   10030955  https://www.airbnb.com/rooms/10030955
# 2   10138784  https://www.airbnb.com/rooms/10138784
# 3   10373872  https://www.airbnb.com/rooms/10373872
# 4   10057826  https://www.airbnb.com/rooms/10057826
# 5   10240767  https://www.airbnb.com/rooms/10240767
# 6   10091713  https://www.airbnb.com/rooms/10091713
# 7   10096773  https://www.airbnb.com/rooms/10096773
# 8    1038163   https://www.airbnb.com/rooms/1038163
# 9   10133554  https://www.airbnb.com/rooms/10133554
# 10  10038496  https://www.airbnb.com/rooms/10038496
# 11  10141950  https://www.airbnb.com/rooms/10141950
# 12  10324377  https://www.airbnb.com/rooms/10324377
# 13  10059244  https://www.airbnb.com/rooms/10059244
# 14  10233856  https://www.airbnb.com/rooms/10233856
# 15  10083468  https://www.airbnb.com/rooms/10083468
# 16  10006546  https://www.airbnb.com/rooms/10006546
# ...

# %%
data = data.dropna(subset = [target])

# %%
X = data[features]
X
# Out:
#     accommodates  bedrooms  beds  number_of_reviews
# 0              2         1   1.0                 12
# 1              2         1   1.0                  0
# 2              2         1   1.0                123
# 3              4         1   2.0                  0
# 4              4         0   2.0                  5
# 5              2         1   1.0                162
# 6              2         0   1.0                 64
# 7              2         1   1.0                  1
# 8              4         1   3.0                135
# 9              3         1   2.0                 29
# 10             4         1   3.0                 70
# 11             2         0   1.0                  1
# 12             1         1   1.0                  0
# 13             2         0   1.0                  0
# 14             3         1   2.0                 22
# 15             2         1   1.0                178
# 16             8         3   5.0                 51
# ...

# %%
Y = data[target]
Y
# Out:
# 0       40.00
# 1      701.00
# 2       46.00
# 3      149.00
# 4      205.00
# 5      487.00
# 6      181.00
# 7      145.00
# 8      269.00
# 9      121.00
# 10     119.00
# 11     966.00
# 12     101.00
# 13      43.00
# 14     400.00
# 15      30.00
# 16      80.00
# 17      50.00
# 18     149.00
# 19     838.00
# 20     317.00
# 21     135.00
# 22     795.00
# 23     100.00
# 24     220.00
# 25     997.00
# 26     117.00
# 27      36.00
# 28      31.00
# 29     150.00
# 30      45.00
# 31     858.00
# 32     100.00
# 33     361.00
# 34     699.00
# 35     138.00
# 36     135.00
# 37     298.00
# 38      40.00
# 39     185.00
# 40      34.00
# 41     933.00
# 42     380.00
# 43    1484.00
# 44     685.00
# 45     187.00
# 46     234.00
# 47     999.00
# 48      60.00
# 49      50.00
# Name: price, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators=20)

# %%
from bson.decimal128 import Decimal128
#x_train = x_train.map(lambda x: float(x.to_decimal()) if isinstance(x, Decimal128) else float(x))
#x_test = x_test.map(lambda x: float(x.to_decimal()) if isinstance(x, Decimal128) else float(x))
y_train = y_train.map(lambda x: float(x.to_decimal()) if isinstance(x, Decimal128) else float(x))
y_test = y_test.map(lambda x: float(x.to_decimal()) if isinstance(x, Decimal128) else float(x))

# %%
y_train
# Out:
# 10     119.0
# 22     795.0
# 30      45.0
# 36     135.0
# 11     966.0
# 19     838.0
# 24     220.0
# 18     149.0
# 35     138.0
# 23     100.0
# 48      60.0
# 15      30.0
# 39     185.0
# 17      50.0
# 16      80.0
# 44     685.0
# 0       40.0
# 5      487.0
# 8      269.0
# 33     361.0
# 2       46.0
# 25     997.0
# 1      701.0
# 42     380.0
# 43    1484.0
# 34     699.0
# 6      181.0
# 14     400.0
# 26     117.0
# 40      34.0
# 13      43.0
# 3      149.0
# 20     317.0
# 47     999.0
# 49      50.0
# 31     858.0
# 46     234.0
# 45     187.0
# 38      40.0
# 7      145.0
# Name: price, dtype: float64

# %%
y_test
# Out:
# 28     31.0
# 29    150.0
# 27     36.0
# 32    100.0
# 21    135.0
# 12    101.0
# 41    933.0
# 9     121.0
# 4     205.0
# 37    298.0
# Name: price, dtype: float64

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=20)

# %%
from sklearn.metrics import mean_absolute_error

# %%
y_pred = model.predict(x_test)
mae = mean_absolute_error(y_pred, y_test)
mae
# Out:
# 306.10169047619047
